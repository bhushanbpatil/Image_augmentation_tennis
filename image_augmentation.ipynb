# %%
from PIL import Image
from PIL import ImageDraw

# BACK IN

yellow_left=450
yellow_up=225
yellow_right=635
yellow_down=270

blue_up=225
blue_right=707
blue_down=523
blue_left=yellow_left-257

green_right=((blue_right+blue_left)/2)+3
green_down=blue_up+100+3
green_left=green_right-(blue_right-blue_left)
green_up=blue_up-100



green_box=(green_left,green_up,green_right,green_down)
blue_box=(blue_left,blue_up,blue_right,blue_down)
yellow_box=(yellow_left,yellow_up,yellow_right,yellow_down)

image = Image.open('img0.jpg')
draw = ImageDraw.Draw(image)
draw.rectangle(yellow_box,outline='yellow', width=3)
draw.rectangle((450,225,707,374),outline='red', width=3)
draw.rectangle((blue_left,blue_up,blue_right,blue_down),outline='blue', width=3)
draw.rectangle((green_left,green_up,green_right,green_down),outline='green', width=3)
draw.arc(blue_box, 270, 0, 'yellow', width=4) #draw circle in black
draw.arc(green_box, 300, 0, 'yellow', width=4)
image.save('bhushan.jpg')
image.show()

# %%
count=0
while(True): 
    if(blue_up>=yellow_down):
        break
    else:
        while(True):
            image = Image.open('img0.jpg')
            draw = ImageDraw.Draw(image)
            count+=1
            green_right=((blue_right+blue_left)/2)+3
            green_down=blue_up+100+3
            green_left=green_right-(blue_right-blue_left)
            green_up=blue_up-100
            if(green_right>=yellow_right):
                break
            else:
                draw = ImageDraw.Draw(image)
#                 draw.rectangle(yellow_box,outline='yellow', width=3)
#                 draw.rectangle((450,225,707,374),outline='red', width=3)
#                 draw.rectangle((blue_left,blue_up,blue_right,blue_down),outline='blue', width=3)
#                 draw.rectangle((green_left,green_up,green_right,green_down),outline='green', width=3)
                draw.arc((blue_left,blue_up,blue_right,blue_down), 270, 0, 'yellow', width=4) #draw circle in black
                draw.arc((green_left,green_up,green_right,green_down), 300, 0, 'yellow', width=4)
                image.save(r'in\service_back_in'+str(count)+'.jpg')
            blue_left+=10
    blue_up+=10
    blue_down-=10
    blue_left=yellow_left-257
print(count)
# Out:
# 190

# %%
# img = Image.open("service_in1.jpg").transpose(Image.FLIP_LEFT_RIGHT)
# img.save('flip_img.jpg')

# %%
#FRONT IN

blue_left=580-270
blue_up=70
blue_right=870
blue_down=430+360

green_up=(blue_up+blue_down)/2
green_right=blue_right +(abs(blue_right-blue_left)/2)-100
green_down=green_up+abs(blue_up-blue_down)
green_left=blue_right-(abs(blue_right-blue_left)/2)+100

yellow_left=640
yellow_up=360
yellow_right=870
yellow_down=430

green_box=(green_left,green_up,green_right,green_down)
blue_box=(blue_left,blue_up,blue_right,blue_down)
yellow_box=(yellow_left,yellow_up,yellow_right,yellow_down)

image = Image.open('img0.jpg')
draw = ImageDraw.Draw(image)
draw.rectangle(yellow_box,outline='yellow', width=3)
draw.rectangle((450,225,707,374),outline='red', width=3)
draw.rectangle((blue_left,blue_up,blue_right,blue_down),outline='blue', width=3)
draw.rectangle((green_left,green_up,green_right,green_down),outline='green', width=3)
draw.arc(blue_box, 270, 0, 'yellow', width=4) #draw circle in black
draw.arc(green_box, 270, 0, 'yellow', width=4)
image.save('aaatest.jpg')
image.show()

# %%
# blue_left=580-270
# blue_up=70
# blue_right=870
# blue_down=430+360

# %%
# blue_left=temp_left
# blue_right=temp_right
count=0
while(True):
#     blue_left=temp_left
#     blue_right=temp_right
    
    if(green_up<=yellow_up):
        break
    else:

        while(True):
            image = Image.open('img0.jpg')
            draw = ImageDraw.Draw(image)
            count+=1
            green_up=abs(blue_up+blue_down)/2
            green_right=blue_right +(abs(blue_right-blue_left)/2)
            green_down=green_up+abs(blue_up-blue_down)-300
            green_left=blue_right-(abs(blue_right-blue_left)/2)
            
            if(blue_right<=yellow_left):
                break
            else:
                draw = ImageDraw.Draw(image)
#                 draw.rectangle(yellow_box,outline='yellow', width=3)
#                 draw.rectangle((450,225,707,374),outline='red', width=3)
#                 draw.rectangle((blue_left,blue_up,blue_right,blue_down),outline='blue', width=3)
#                 draw.rectangle((green_left,green_up,green_right,green_down),outline='green', width=3)
                draw.arc((blue_left,blue_up,blue_right,blue_down), 270, 0, 'yellow', width=4) #draw circle in black
                draw.arc((green_left,green_up,green_right,green_down), 270, 0, 'yellow', width=4)
                image.save(r'in\service_front_in'+str(count)+'.jpg')
            blue_left+=10
            blue_right-=10
        
        blue_down-=10
        blue_left=580-270
        blue_right=870
print(count)
# Out:
# 360

# %%
#BACK OUT

yellow_left=450
yellow_up=225
yellow_right=635
yellow_down=270

red_left=450-80
red_up=225-50
red_right=635+70
red_down=270+50

blue_up=red_up
blue_right=707
blue_down=523
blue_left=red_left-337

green_right=((blue_right+blue_left)/2)+3
green_down=blue_up+100+3
green_left=green_right-(blue_right-blue_left)
green_up=blue_up-100


green_box=(green_left,green_up,green_right,green_down)
blue_box=(blue_left,blue_up,blue_right,blue_down)
yellow_box=(yellow_left,yellow_up,yellow_right,yellow_down)
red_box=(red_left,red_up,red_right,red_down)

image = Image.open('img0.jpg')
draw = ImageDraw.Draw(image)
draw.rectangle(yellow_box,outline='yellow', width=3)
draw.rectangle(red_box,outline='red', width=3)
draw.rectangle((blue_left,blue_up,blue_right,blue_down),outline='blue', width=3)
draw.rectangle((green_left,green_up,green_right,green_down),outline='green', width=3)
draw.arc(blue_box, 270, 0, 'yellow', width=4) #draw circle in black
draw.arc(green_box, 300, 0, 'yellow', width=4)
image.save('bhushan.jpg')
image.show()

# %%
blue_up=red_up
blue_right=707
blue_down=523
blue_left=red_left-337
image = Image.open('img0.jpg')
count=0
while(True): 
    if(blue_up>=red_down):
        break
    else:
        while(True):
            image = Image.open('img0.jpg')
            draw = ImageDraw.Draw(image)
            count+=1
            green_right=((blue_right+blue_left)/2)+3
            green_down=blue_up+100+3
            green_left=green_right-(blue_right-blue_left)
            green_up=blue_up-100
            if(green_right>=red_right):
                break
            elif((green_right<yellow_left or green_right>yellow_right) or (blue_up<yellow_up or blue_up>yellow_down)):
                draw = ImageDraw.Draw(image)
#                 draw.rectangle(yellow_box,outline='yellow', width=3)
#                 draw.rectangle(red_box,outline='red', width=3)
#                 draw.rectangle((blue_left,blue_up,blue_right,blue_down),outline='blue', width=3)
#                 draw.rectangle((green_left,green_up,green_right,green_down),outline='green', width=3)
                draw.arc((blue_left,blue_up,blue_right,blue_down), 270, 0, 'yellow', width=4) #draw circle in black
                draw.arc((green_left,green_up,green_right,green_down), 300, 0, 'yellow', width=4)
                image.save(r'out\service_back_out'+str(count)+'.jpg')
            blue_left+=20
    blue_up+=20
    blue_down-=20
    blue_left=red_left-337
print(count)
# Out:
# 280

# %%
#FRONT OUT

yellow_left=640
yellow_up=360
yellow_right=870
yellow_down=430

red_left=yellow_left-80
red_up=yellow_up
red_right=yellow_right+80
red_down=yellow_down+80

blue_left=580-270
blue_up=70
blue_right=red_right
blue_down=red_down+red_down-blue_up

green_up=(blue_up+blue_down)/2
green_right=blue_right +(abs(blue_right-blue_left)/2)-100
green_down=green_up+abs(blue_up-blue_down)
green_left=blue_right-(abs(blue_right-blue_left)/2)+100

green_box=(green_left,green_up,green_right,green_down)
blue_box=(blue_left,blue_up,blue_right,blue_down)
yellow_box=(yellow_left,yellow_up,yellow_right,yellow_down)
red_box=(red_left,red_up,red_right,red_down)

image = Image.open('img0.jpg')
draw = ImageDraw.Draw(image)
draw.rectangle(yellow_box,outline='yellow', width=3)
draw.rectangle(red_box,outline='red', width=3)
draw.rectangle((blue_left,blue_up,blue_right,blue_down),outline='blue', width=3)
draw.rectangle((green_left,green_up,green_right,green_down),outline='green', width=3)
draw.arc(blue_box, 270, 0, 'yellow', width=4) #draw circle in black
draw.arc(green_box, 270, 0, 'yellow', width=4)
image.save('aaatest.jpg')
image.show()

# %%
blue_left=580-270
blue_up=70
blue_right=red_right
blue_down=red_down+red_down-blue_up
image = Image.open('img0.jpg')
count=0
while(True): 
    if(green_up<=red_up):
        break
    else:
        while(True):
            image = Image.open('img0.jpg')
            draw = ImageDraw.Draw(image)
            count+=1
            green_up=(blue_up+blue_down)/2
            green_right=blue_right +(abs(blue_right-blue_left)/2)-100
            green_down=green_up+abs(blue_up-blue_down)
            green_left=blue_right-(abs(blue_right-blue_left)/2)+100
            if(blue_right<=red_left):
                break
            elif(blue_right<=blue_left or green_right<=green_left):
                blue_left+=10
                blue_right-=10
                continue
            elif((blue_right>yellow_right or blue_right<yellow_left) or (green_up<yellow_up or green_up>yellow_down)):
                draw = ImageDraw.Draw(image)
#                 draw.rectangle(yellow_box,outline='yellow', width=3)
#                 draw.rectangle(red_box,outline='red', width=3)
#                 draw.rectangle((blue_left,blue_up,blue_right,blue_down),outline='blue', width=3)
#                 draw.rectangle((green_left,green_up,green_right,green_down),outline='green', width=3)
                draw.arc((blue_left,blue_up,blue_right,blue_down), 270, 0, 'yellow', width=4) #draw circle in black
                draw.arc((green_left,green_up,green_right,green_down), 270, 0, 'yellow', width=4)
                image.save(r'out\service_front_out'+str(count)+'.jpg')
            blue_left+=10
            blue_right-=10
    blue_down-=20
    blue_left=580-270
    blue_right=red_right
print(count)
# Out:
# 640
